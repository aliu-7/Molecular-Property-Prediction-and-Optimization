# %% [markdown]
# <a href="https://colab.research.google.com/github/aliu-7/Molecular-Property-Prediction-and-Optimization/blob/main/4_2_4_Training_a_GNN_Model_for_Molecular_Property_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installations

# %%
# Install RDKit (via conda-forge) using a Colab-friendly wrapper
# !pip install -q condacolab
import condacolab
condacolab.install()

# After runtime restarts automatically, run this:
# !mamba install -c conda-forge rdkit -y

# Reinstall PyTorch Geometric (CPU version shown here; adjust for GPU if needed)
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-2.0.0+cpu.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-2.0.0+cpu.html
# !pip install -q torch-geometric
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:10
# 🔁 Restarting kernel...
#
# Looking for: ['rdkit']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   2%
# conda-forge/noarch     4%[+] 0.3s
# conda-forge/linux-64   9%
# conda-forge/noarch    20%[+] 0.4s
# conda-forge/linux-64  13%
# conda-forge/noarch    34%[+] 0.5s
# conda-forge/linux-64  18%
# conda-forge/noarch    45%[+] 0.6s
# conda-forge/linux-64  23%
# conda-forge/noarch    57%[+] 0.7s
# conda-forge/linux-64  28%
# conda-forge/noarch    67%[+] 0.8s
# conda-forge/linux-64  32%
# conda-forge/noarch    75%[+] 0.9s
# conda-forge/linux-64  39%
# conda-forge/noarch    89%conda-forge/noarch
# [+] 1.0s
# conda-forge/linux-64  45%[+] 1.1s
# conda-forge/linux-64  58%[+] 1.2s
# conda-forge/linux-64  70%[+] 1.3s
# conda-forge/linux-64  80%[+] 1.4s
# conda-forge/linux-64  86%[+] 1.5s
# conda-forge/linux-64  88%[+] 1.6s
# conda-forge/linux-64  92%[+] 1.7s
# conda-forge/linux-64  96%[+] 1.8s
# conda-forge/linux-64  99%[+] 1.9s
# conda-forge/linux-64  99%[+] 2.0s
# conda-forge/linux-64  99%[+] 2.1s
# conda-forge/linux-64  99%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - rdkit
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                          Version  Build                 Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#   + icu                               75.1  he02047a_0            conda-forge       12MB
#   + xorg-libice                      1.1.2  hb9d3cd8_0            conda-forge       59kB
#   + libjpeg-turbo                    3.1.0  hb9d3cd8_0            conda-forge      629kB
#   + libwebp-base                     1.5.0  h851e524_0            conda-forge      430kB
#   + libpng                          1.6.49  h943b412_0            conda-forge      290kB
#   + kiwisolver                       1.4.7  py311hd18a35c_0       conda-forge       72kB
#   + qhull                           2020.2  h434a139_5            conda-forge      553kB
#   + pthread-stubs                      0.4  hb9d3cd8_1002         conda-forge        8kB
#   + xorg-libxdmcp                    1.1.5  hb9d3cd8_0            conda-forge       20kB
#   + xorg-libxau                     1.0.12  hb9d3cd8_0            conda-forge       15kB
#   + lerc                             4.0.0  h0aef613_1            conda-forge      264kB
#   + libgfortran5                    14.2.0  hf1ad2bd_2            conda-forge        1MB
#   + libbrotlicommon                  1.1.0  hb9d3cd8_2            conda-forge       69kB
#   + unicodedata2                    16.0.0  py311h9ecbd09_0       conda-forge      405kB
#   + pixman                          0.46.2  h29eaf8c_0            conda-forge      402kB
#   + greenlet                         3.2.3  py311hfdbb021_0       conda-forge      240kB
#   + libntlm                            1.8  hb9d3cd8_0            conda-forge       33kB
#   + libdeflate                        1.23  h86f0d12_0            conda-forge       73kB
#   + pcre2                            10.44  hc749103_2            conda-forge      956kB
#   + libboost                        1.86.0  h6c02f8c_3            conda-forge        3MB
#   + xorg-libsm                       1.2.6  he73a12e_0            conda-forge       28kB
#   + libfreetype6                    2.13.3  h48d6fc4_1            conda-forge      380kB
#   + libxcb                          1.17.0  h8a09558_0            conda-forge      396kB
#   + libgfortran                     14.2.0  h69a702a_2            conda-forge       54kB
#   + libbrotlienc                     1.1.0  hb9d3cd8_2            conda-forge      282kB
#   + libbrotlidec                     1.1.0  hb9d3cd8_2            conda-forge       33kB
#   + libtiff                          4.7.0  hd9ff511_3            conda-forge      428kB
#   + libglib                         2.82.2  h2ff4ddf_1            conda-forge        4MB
#   + libfreetype                     2.13.3  ha770c72_1            conda-forge        8kB
#   + xorg-libx11                     1.8.12  h4f16b4b_0            conda-forge      836kB
#   + libopenblas                     0.3.29  pthreads_h94d23a6_0   conda-forge        6MB
#   + brotli-bin                       1.1.0  hb9d3cd8_2            conda-forge       19kB
#   + openjpeg                         2.5.3  h5fbd93e_0            conda-forge      343kB
#   + lcms2                             2.17  h717163a_0            conda-forge      248kB
#   + freetype                        2.13.3  ha770c72_1            conda-forge      172kB
#   + xorg-libxrender                 0.9.12  hb9d3cd8_0            conda-forge       33kB
#   + xorg-libxext                     1.3.6  hb9d3cd8_0            conda-forge       50kB
#   + libblas                          3.9.0  31_h59b9bed_openblas  conda-forge       17kB
#   + brotli                           1.1.0  hb9d3cd8_2            conda-forge       19kB
#   + pillow                          11.2.1  py311h1322bbf_0       conda-forge       43MB
#   + fontconfig                      2.15.0  h7e30c49_1            conda-forge      266kB
#   + libcblas                         3.9.0  31_he106b2a_openblas  conda-forge       17kB
#   + liblapack                        3.9.0  31_h7ac8fdf_openblas  conda-forge       17kB
#   + numpy                            2.3.0  py311h519dc76_0       conda-forge        9MB
#   + contourpy                        1.3.2  py311hd18a35c_0       conda-forge      278kB
#   + libboost-python                 1.86.0  py311h5b7b71f_3       conda-forge      121kB
#   + font-ttf-dejavu-sans-mono         2.37  hab24e00_0            conda-forge      397kB
#   + font-ttf-inconsolata             3.000  h77eed37_0            conda-forge       97kB
#   + font-ttf-source-code-pro         2.038  h77eed37_0            conda-forge      701kB
#   + font-ttf-ubuntu                   0.83  h77eed37_3            conda-forge        2MB
#   + pytz                            2025.2  pyhd8ed1ab_0          conda-forge      189kB
#   + python-tzdata                   2025.2  pyhd8ed1ab_0          conda-forge      144kB
#   + cycler                          0.12.1  pyhd8ed1ab_1          conda-forge       13kB
#   + pyparsing                        3.2.3  pyhd8ed1ab_1          conda-forge       96kB
#   + munkres                          1.1.4  pyhd8ed1ab_1          conda-forge       16kB
#   + six                             1.17.0  pyhd8ed1ab_0          conda-forge       16kB
#   + typing_extensions               4.14.0  pyhe01879c_0          conda-forge       51kB
#   + chardet                          5.2.0  pyhd8ed1ab_3          conda-forge      132kB
#   + freetype-py                      2.3.0  pyhd8ed1ab_0          conda-forge       59kB
#   + fonts-conda-forge                    1  0                     conda-forge        4kB
#   + python-dateutil            2.9.0.post0  pyhe01879c_2          conda-forge      233kB
#   + typing-extensions               4.14.0  h32cad80_0            conda-forge       90kB
#   + fonts-conda-ecosystem                1  0                     conda-forge        4kB
#   + fonttools                       4.58.4  py311h2dc5d0c_0       conda-forge        3MB
#   + pandas                           2.3.0  py311h7db5c69_0       conda-forge       15MB
#   + sqlalchemy                      2.0.41  py311h9ecbd09_0       conda-forge        4MB
#   + cairo                           1.18.4  h3394656_0            conda-forge      978kB
#   + cyrus-sasl                      2.1.28  hd9c7081_0            conda-forge      210kB
#   + matplotlib-base                 3.10.3  py311h2b939e6_0       conda-forge        8MB
#   + pycairo                         1.27.0  py311h124c5f0_0       conda-forge      116kB
#   + librdkit                     2025.03.3  h84b0b3c_0            conda-forge        9MB
#   + openldap                        2.6.10  he970967_0            conda-forge      780kB
#   + libpq                             17.5  h27ae623_0            conda-forge        3MB
#   + rlpycairo                        0.2.0  pyhd8ed1ab_0          conda-forge       15kB
#   + reportlab                        4.4.1  py311h9ecbd09_0       conda-forge        3MB
#   + rdkit                        2025.03.3  py311h4bf1da0_0       conda-forge       20MB
#
#   Change:
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#   - libxml2                         2.13.5  h0d44e9d_1            conda-forge     Cached
#   + libxml2                         2.13.5  h8d12d68_1            conda-forge      691kB
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates             2024.12.14  hbcca054_0            conda-forge     Cached
#   + ca-certificates              2025.6.15  hbd8a1cb_0            conda-forge      151kB
#   - certifi                     2024.12.14  pyhd8ed1ab_0          conda-forge     Cached
#   + certifi                      2025.6.15  pyhd8ed1ab_0          conda-forge      155kB
#   - openssl                          3.4.0  h7b32b05_1            conda-forge     Cached
#   + openssl                          3.5.0  h7b32b05_1            conda-forge        3MB
#
#   Summary:
#
#   Install: 76 packages
#   Change: 1 packages
#   Upgrade: 3 packages
#
#   Total download: 163MB
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (6)   1%
# Extracting         0%xorg-libice                                         58.6kB @ 593.3kB/s  0.1s
# libjpeg-turbo                                      628.9kB @   4.9MB/s  0.1s
# libwebp-base                                       430.0kB @   2.9MB/s  0.2s
# kiwisolver                                          72.4kB @ 480.3kB/s  0.1s
# xorg-libxdmcp                                       19.9kB @ 113.9kB/s  0.0s
# libbrotlicommon                                     68.9kB @ 356.3kB/s  0.0s
# [+] 0.2s
# Downloading  (5)   5%
# Extracting   (4)  ⣾  icu                                                 12.1MB @  60.3MB/s  0.2s
# libdeflate                                          72.8kB @ 343.6kB/s  0.0s
# libgfortran5                                         1.5MB @   6.5MB/s  0.1s
# libbrotlidec                                        32.7kB @ 126.1kB/s  0.0s
# libxcb                                             395.9kB @   1.5MB/s  0.1s
# libxml2                                            690.6kB @   2.6MB/s  0.1s
# libfreetype                                          7.7kB @  27.3kB/s  0.1s
# brotli-bin                                          18.9kB @  64.2kB/s  0.0s
# openjpeg                                           343.0kB @   1.2MB/s  0.0s
# [+] 0.3s
# Downloading  (5)  11%
# Extracting  (10)  ⣾  libblas                                             16.9kB @  51.9kB/s  0.1s
# fontconfig                                         265.6kB @ 814.6kB/s  0.0s
# font-ttf-dejavu-sans-mono                          397.4kB @   1.2MB/s  0.0s
# font-ttf-inconsolata                                96.5kB @ 252.7kB/s  0.1s
# pyparsing                                           96.0kB @ 248.9kB/s  0.0s
# libpng                                             289.5kB @ 746.1kB/s  0.4s
# font-ttf-source-code-pro                           700.8kB @   1.8MB/s  0.1s
# [+] 0.4s
# Downloading  (5)  15%
# Extracting  (16)  ⣾  numpy                                                9.1MB @  22.2MB/s  0.1s
# fonts-conda-forge                                    4.1kB @   9.8kB/s  0.0s
# fonts-conda-ecosystem                                3.7kB @   8.5kB/s  0.0s
# typing_extensions                                   51.0kB @ 117.5kB/s  0.1s
# cyrus-sasl                                         209.8kB @ 473.5kB/s  0.0s
# rlpycairo                                           14.9kB @  30.5kB/s  0.1s
# lerc                                               264.2kB @ 533.8kB/s  0.1s
# qhull                                              552.9kB @   1.1MB/s  0.1s
# [+] 0.5s
# Downloading  (5)  21%
# Extracting  (21)  ⣾  openssl                                              3.1MB @   6.1MB/s  0.1s
# libntlm                                             33.4kB @  62.4kB/s  0.0s
# greenlet                                           239.5kB @ 446.0kB/s  0.0s
# librdkit                                             9.2MB @  17.1MB/s  0.1s
# libfreetype6                                       380.1kB @ 673.8kB/s  0.1s
# lcms2                                              248.0kB @ 434.3kB/s  0.0s
# libcblas                                            16.8kB @  28.7kB/s  0.0s
# freetype                                           172.4kB @ 289.5kB/s  0.1s
# [+] 0.6s
# Downloading  (5)  26%
# Extracting  (29)  ⣾  libboost-python                                    121.0kB @ 199.6kB/s  0.0s
# cycler                                              13.4kB @  21.6kB/s  0.0s
# libglib                                              3.9MB @   6.3MB/s  0.1s
# chardet                                            132.2kB @ 205.3kB/s  0.0s
# typing-extensions                                   90.3kB @ 140.2kB/s  0.0s
# font-ttf-ubuntu                                      1.6MB @   2.5MB/s  0.1s
# sqlalchemy                                           3.6MB @   5.3MB/s  0.1s
# pycairo                                            116.3kB @ 171.8kB/s  0.1s
# [+] 0.7s
# Downloading  (5)  33%
# Extracting  (39)  ⣾  unicodedata2                                       405.0kB @ 567.1kB/s  0.1s
# libgfortran                                         53.7kB @  73.3kB/s  0.1s
# reportlab                                            2.8MB @   3.8MB/s  0.1s
# libbrotlienc                                       281.8kB @ 372.1kB/s  0.1s
# xorg-libxext                                        50.1kB @  66.1kB/s  0.1s
# liblapack                                           16.8kB @  21.9kB/s  0.0s
# certifi                                            155.4kB @ 198.7kB/s  0.0s
# [+] 0.8s
# Downloading  (5)  38%
# Extracting  (45)  ⣾  munkres                                             15.9kB @  19.3kB/s  0.1s
# six                                                 16.4kB @  19.9kB/s  0.1s
# pixman                                             402.2kB @ 451.2kB/s  0.1s
# [+] 0.9s
# Downloading  (5)  42%
# Extracting  (46)  ⣾  pcre2                                              956.2kB @   1.0MB/s  0.1s
# fonttools                                            2.9MB @   3.1MB/s  0.2s
# libpq                                                2.7MB @   2.7MB/s  0.2s
# [+] 1.0s
# Downloading  (5)  44%
# Extracting  (49)  ⣾  contourpy                                          278.4kB @ 273.6kB/s  0.1s
# python-dateutil                                    233.3kB @ 218.3kB/s  0.1s
# [+] 1.1s
# Downloading  (5)  47%
# Extracting  (52)  ⣾  xorg-libxau                                         14.8kB @  13.0kB/s  0.1s
# [+] 1.2s
# Downloading  (5)  52%
# Extracting  (52)  ⣾  libtiff                                            428.2kB @ 351.8kB/s  0.1s
# brotli                                              19.3kB @  15.2kB/s  0.0s
# [+] 1.3s
# Downloading  (5)  59%
# Extracting  (53)  ⣾  python-tzdata                                      144.2kB @ 108.7kB/s  0.1s
# libopenblas                                          5.9MB @   4.5MB/s  0.4s
# [+] 1.4s
# Downloading  (5)  62%
# Extracting  (54)  ⣾  openldap                                           780.3kB @ 552.7kB/s  0.1s
# xorg-libxrender                                     33.0kB @  22.4kB/s  0.1s
# [+] 1.5s
# Downloading  (5)  69%
# Extracting  (55)  ⣾  rdkit                                               20.1MB @  13.3MB/s  0.9s
# freetype-py                                         58.9kB @  38.2kB/s  0.1s
# xorg-libsm                                          27.6kB @  17.4kB/s  0.0s
# [+] 1.6s
# Downloading  (5)  73%
# Extracting  (57)  ⣾  pthread-stubs                                        8.3kB @   5.0kB/s  0.0s
# [+] 1.7s
# Downloading  (5)  77%
# Extracting  (58)  ⣾  pytz                                               189.0kB @ 110.6kB/s  0.1s
# libboost                                             2.9MB @   1.7MB/s  0.2s
# ca-certificates                                    151.1kB @  85.5kB/s  0.0s
# matplotlib-base                                      8.3MB @   4.7MB/s  0.4s
# [+] 1.8s
# Downloading  (4)  82%
# Extracting  (62)  ⣾  pandas                                              15.3MB @   8.4MB/s  0.8s
# cairo                                              978.1kB @ 531.0kB/s  0.1s
# xorg-libx11                                        835.9kB @ 453.6kB/s  0.1s
# [+] 1.9s
# Downloading  (1)  85%
# Extracting  (65)  ⣾  [+] 2.0s
# Downloading  (1)  88%
# Extracting  (65)  ⣾  [+] 2.1s
# Downloading  (1)  91%
# Extracting  (65)  ⣾  [+] 2.2s
# Downloading  (1)  95%
# Extracting  (64)  ⣾  [+] 2.3s
# Downloading  (1)  99%
# Extracting  (63)  ⣾  pillow                                              43.5MB @  18.4MB/s  1.4s
# [+] 2.4s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 53.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.5 MB/s eta 0:00:00

# %% [markdown]
# # Loading and Preprocessing Dataset

# %%
# Step 2: Load and preprocess the dataset
import pandas as pd
from rdkit import Chem
from torch_geometric.data import Data
from sklearn.model_selection import train_test_split
import torch
from torch.nn.functional import one_hot
from torch_geometric.loader import DataLoader

# Node and bond feature helpers
def atom_features(atom):
    return torch.tensor([
        atom.GetAtomicNum(),
        atom.GetDegree(),
        int(atom.GetIsAromatic())
    ], dtype=torch.float)

def bond_features(bond):
    bond_types = {
        Chem.rdchem.BondType.SINGLE: 0,
        Chem.rdchem.BondType.DOUBLE: 1,
        Chem.rdchem.BondType.TRIPLE: 2,
        Chem.rdchem.BondType.AROMATIC: 3
    }
    btype = bond_types.get(bond.GetBondType(), 4)
    return one_hot(torch.tensor(btype), num_classes=5).float()

def smiles_to_data(smiles, label):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None: return None

    x = torch.stack([atom_features(atom) for atom in mol.GetAtoms()])
    edge_index, edge_attr = [], []

    for bond in mol.GetBonds():
        i, j = bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()
        feat = bond_features(bond)
        edge_index += [[i, j], [j, i]]
        edge_attr += [feat, feat]

    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    edge_attr = torch.stack(edge_attr)

    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=torch.tensor([label], dtype=torch.float))

# Step 3: Load BBBP and convert to graphs
url = "https://raw.githubusercontent.com/Data-Chemist-Handbook/Data-Chemist-Handbook.github.io/refs/heads/master/_pages/BBBP.csv"
df = pd.read_csv(url)

graph_list = [smiles_to_data(smi, lbl) for smi, lbl in zip(df['smiles'], df['p_np'])]
graph_list = [g for g in graph_list if g is not None]

# Step 4: Split and load data
train_data, test_data = train_test_split(graph_list, test_size=0.2, random_state=42)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32)
# Out:
# /usr/local/lib/python3.11/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /usr/local/lib/python3.11/site-packages/torch_scatter/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /usr/local/lib/python3.11/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /usr/local/lib/python3.11/site-packages/torch_sparse/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# [05:27:15] Explicit valence for atom # 1 N, 4, is greater than permitted
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:15] Explicit valence for atom # 6 N, 4, is greater than permitted
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:15] Explicit valence for atom # 6 N, 4, is greater than permitted
# [05:27:15] WARNING: not removing hydrogen atom without neighbors
# [05:27:16] WARNING: not removing hydrogen atom without neighbors
# [05:27:16] WARNING: not removing hydrogen atom without neighbors
# [05:27:16] WARNING: not removing hydrogen atom without neighbors
# [05:27:16] Explicit valence for atom # 11 N, 4, is greater than permitted
# [05:27:16] Explicit valence for atom # 12 N, 4, is greater than permitted
# [05:27:16] Explicit valence for atom # 5 N, 4, is greater than permitted
# [05:27:16] Explicit valence for atom # 5 N, 4, is greater than permitted
# [05:27:16] Explicit valence for atom # 5 N, 4, is greater than permitted
# [05:27:16] Explicit valence for atom # 5 N, 4, is greater than permitted
# [05:27:16] Explicit valence for atom # 5 N, 4, is greater than permitted
# [05:27:16] WARNING: not removing hydrogen atom without neighbors
# [05:27:16] WARNING: not removing hydrogen atom without neighbors
# [05:27:16] Explicit valence for atom # 5 N, 4, is greater than permitted
# [05:27:16] WARNING: not removing hydrogen atom without neighbors
# [05:27:17] WARNING: not removing hydrogen atom without neighbors
# [05:27:17] WARNING: not removing hydrogen atom without neighbors
# [05:27:17] WARNING: not removing hydrogen atom without neighbors
# [05:27:17] WARNING: not removing hydrogen atom without neighbors
# [05:27:17] WARNING: not removing hydrogen atom without neighbors
# [05:27:17] WARNING: not removing hydrogen atom without neighbors
# [05:27:17] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:18] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors
# [05:27:19] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# # Define the GCN Model

# %%
import torch.nn as nn
from torch_geometric.nn import GCNConv, global_mean_pool

class GCNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = GCNConv(3, 64)
        self.conv2 = GCNConv(64, 64)
        self.fc = nn.Linear(64, 1)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch)
        return torch.sigmoid(self.fc(x))

# %% [markdown]
# # Train and Evaluate the Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = GCNModel().to(device)

import torch.optim as optim

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
def train():
    model.train()
    for batch in train_loader:
        batch = batch.to(device)
        optimizer.zero_grad()
        output = model(batch).squeeze()
        loss = criterion(output, batch.y)
        loss.backward()
        optimizer.step()

# Evaluation loop
def test():
    model.eval()
    correct = total = 0
    with torch.no_grad():
        for batch in test_loader:
            batch = batch.to(device)
            output = model(batch).squeeze()
            pred = (output > 0.5).float()
            correct += (pred == batch.y).sum().item()
            total += batch.y.size(0)
    return correct / total

# Run training
for epoch in range(5):
    train()
    acc = test()
    print(f"Epoch {epoch+1}, Test Accuracy: {acc:.2f}")
# Out:
# Epoch 1, Test Accuracy: 0.76
# Epoch 2, Test Accuracy: 0.76
# Epoch 3, Test Accuracy: 0.76
# Epoch 4, Test Accuracy: 0.76
# Epoch 5, Test Accuracy: 0.76
